# %%
# 미분 함수
def numerical_derivative(f, x):
    delta_x=1e-4
    return (f(x+delta_x)-f(x-delta_x))/(2*delta_x)

# %%
# f(x) = x**2 함수를 파이썬 함수로 표현
def my_func1(x):
    return x**2

# %%
# derivative 유도하다, (수학 함수)를 미분하다
result1=numerical_derivative(my_func1, 3)
print(result1)
# Out:
# 6.000000000012662

# %%
import numpy as np

# %%
# 수치미분 다변수
def numerical_derivative2(f, x):
    delta_x=1e-4
    grad=np.zeros_like(x)

    it = np.nditer(x,flags=['multi_index'], op_flags=['readwrite'])

    while not it.finished:
        idx=it.multi_index

        tmp_val=x[idx]
        x[idx]=float(tmp_val)+delta_x
        fx1=f(x)

        x[idx]=tmp_val = delta_x
        fx2=f(x)
        grad[idx]=(fx1-fx2)/(2*delta_x)

        x[idx]=tmp_val
        it.iternext()

    return grad

# %%
def func2(input):
    x=input[0]
    y=input[1]
    return (2*x + 3*x*y + np.power(y,3)) 

# f(x, y) = 2x + 3xy + y**3

# %%
result2=numerical_derivative2(func2, np.array([1.0, 2.0]))
print(result2)
# Out:
# [40000.     40009.0003]

# %%
result3=numerical_derivative2(my_func1, np.array([3]))
print(result3)
# Out:
# [45000]
# C:\Users\it\AppData\Local\Temp\ipykernel_4016\1306980589.py:16: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   grad[idx]=(fx1-fx2)/(2*delta_x)

# %%
arr1=np.array([[1.0, 2.0],[3.0, 4.0]])
arr1
# Out:
# array([[1., 2.],
#        [3., 4.]])

# %%
def func4(input):
    w=input[0][0]
    x=input[0][1]
    y=input[1][0]
    z=input[1][1]
    return (w*x + w*y*z + 3*w + z**2)

# %%
result4=numerical_derivative2(func4, arr1)
print(result4)
# Out:
# [[8.50000000e+04 1.00000000e+00]
#  [6.00000000e+00 8.00040002e+04]]
