# %%
# !pip install torch

# %%
# !pip install torch torchvision torchaudio
# Out:
# ...
#    ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
#    ---------------------------------------- 4.3/4.3 MB 23.0 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    ---------------------------------------- 0/2 [torchvision]
#    -------------------- ------------------- 1/2 [torchaudio]
#    -------------------- ------------------- 1/2 [torchaudio]
#    ---------------------------------------- 2/2 [torchaudio]
#
# ...

# %%
# import torch

import torch
print(torch.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import torch
#
# ModuleNotFoundError: No module named 'torch'
